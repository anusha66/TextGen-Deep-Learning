# %%
import json
file = open('attentions.txt', 'r')

# %%
#24 attributes and 26 players

# %%
filedata = file.read()

# %%
type(filedata)
# Out:
# str

# %%
import numpy as np
file = open('attentions.txt', 'r')
lines = file.readlines()
print(len(lines))
values = []
for line in lines:
    tokens = line.strip().split()
    row = []
    for token in tokens:
        if '~' not in token:
            row.append(float(token))
    if len(row) > 0:
        values.append(row)
# Out:
# 792

# %%
values = np.load('attentions.npy').T

# %%
lines = [('FIRST_NAME', 'Lucas Nogueira', 'Lucas'), ('FIRST_NAME', 'Delon Wright', 'Delon'), ('FIRST_NAME', 'Bismack Biyombo', 'Bismack'), ('FIRST_NAME', 'Cory Joseph', 'Cory'), ('FIRST_NAME', 'Norman Powell', 'Norman'), ('FIRST_NAME', 'DeMarre Carroll', 'DeMarre'), ('FIRST_NAME', "Kyle O'Quinn", 'Kyle'), ('FIRST_NAME', 'Lance Thomas', 'Lance'), ('FIRST_NAME', 'Arron Afflalo', 'Arron'), ('FIRST_NAME', 'Robin Lopez', 'Robin'), ('FIRST_NAME', 'Derrick Williams', 'Derrick'), ('FIRST_NAME', 'Langston Galloway', 'Langston'), ('FIRST_NAME', 'Sasha Vujacic', 'Sasha'), ('FIRST_NAME', 'Kevin Seraphin', 'Kevin'), ('FIRST_NAME', 'Lou Amundson', 'Lou'), ('FIRST_NAME', 'Jerian Grant', 'Jerian'), ('FIRST_NAME', 'Jose Calderon', 'Jose'), ('FIRST_NAME', 'Carmelo Anthony', 'Carmelo'), ('FIRST_NAME', 'James Johnson', 'James'), ('FIRST_NAME', 'Kristaps Porzingis', 'Kristaps'), ('FIRST_NAME', 'Jonas Valanciunas', 'Jonas'), ('FIRST_NAME', 'Luis Scola', 'Luis'), ('FIRST_NAME', 'Kyle Lowry', 'Kyle'), ('FIRST_NAME', 'DeMar DeRozan', 'DeMar'), ('FIRST_NAME', 'Terrence Ross', 'Terrence'), ('FIRST_NAME', 'Patrick Patterson', 'Patrick'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('MIN', 'Lucas Nogueira', 'N/A'), ('MIN', 'Delon Wright', 'N/A'), ('MIN', 'Bismack Biyombo', '20'), ('MIN', 'Cory Joseph', '24'), ('MIN', 'Norman Powell', '4'), ('MIN', 'DeMarre Carroll', 'N/A'), ('MIN', "Kyle O'Quinn", '19'), ('MIN', 'Lance Thomas', '25'), ('MIN', 'Arron Afflalo', '38'), ('MIN', 'Robin Lopez', '25'), ('MIN', 'Derrick Williams', '28'), ('MIN', 'Langston Galloway', '31'), ('MIN', 'Sasha Vujacic', '24'), ('MIN', 'Kevin Seraphin', '15'), ('MIN', 'Lou Amundson', '9'), ('MIN', 'Jerian Grant', '25'), ('MIN', 'Jose Calderon', 'N/A'), ('MIN', 'Carmelo Anthony', 'N/A'), ('MIN', 'James Johnson', '16'), ('MIN', 'Kristaps Porzingis', 'N/A'), ('MIN', 'Jonas Valanciunas', '28'), ('MIN', 'Luis Scola', '19'), ('MIN', 'Kyle Lowry', '41'), ('MIN', 'DeMar DeRozan', '36'), ('MIN', 'Terrence Ross', '22'), ('MIN', 'Patrick Patterson', '29'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FGM', 'Lucas Nogueira', 'N/A'), ('FGM', 'Delon Wright', 'N/A'), ('FGM', 'Bismack Biyombo', '2'), ('FGM', 'Cory Joseph', '5'), ('FGM', 'Norman Powell', '0'), ('FGM', 'DeMarre Carroll', 'N/A'), ('FGM', "Kyle O'Quinn", '4'), ('FGM', 'Lance Thomas', '3'), ('FGM', 'Arron Afflalo', '7'), ('FGM', 'Robin Lopez', '3'), ('FGM', 'Derrick Williams', '3'), ('FGM', 'Langston Galloway', '6'), ('FGM', 'Sasha Vujacic', '5'), ('FGM', 'Kevin Seraphin', '2'), ('FGM', 'Lou Amundson', '1'), ('FGM', 'Jerian Grant', '4'), ('FGM', 'Jose Calderon', 'N/A'), ('FGM', 'Carmelo Anthony', 'N/A'), ('FGM', 'James Johnson', '0'), ('FGM', 'Kristaps Porzingis', 'N/A'), ('FGM', 'Jonas Valanciunas', '4'), ('FGM', 'Luis Scola', '3'), ('FGM', 'Kyle Lowry', '8'), ('FGM', 'DeMar DeRozan', '9'), ('FGM', 'Terrence Ross', '2'), ('FGM', 'Patrick Patterson', '4'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('REB', 'Lucas Nogueira', 'N/A'), ('REB', 'Delon Wright', 'N/A'), ('REB', 'Bismack Biyombo', '2'), ('REB', 'Cory Joseph', '7'), ('REB', 'Norman Powell', '1'), ('REB', 'DeMarre Carroll', 'N/A'), ('REB', "Kyle O'Quinn", '6'), ('REB', 'Lance Thomas', '2'), ('REB', 'Arron Afflalo', '2'), ('REB', 'Robin Lopez', '8'), ('REB', 'Derrick Williams', '5'), ('REB', 'Langston Galloway', '4'), ('REB', 'Sasha Vujacic', '6'), ('REB', 'Kevin Seraphin', '1'), ('REB', 'Lou Amundson', '2'), ('REB', 'Jerian Grant', '4'), ('REB', 'Jose Calderon', 'N/A'), ('REB', 'Carmelo Anthony', 'N/A'), ('REB', 'James Johnson', '1'), ('REB', 'Kristaps Porzingis', 'N/A'), ('REB', 'Jonas Valanciunas', '18'), ('REB', 'Luis Scola', '4'), ('REB', 'Kyle Lowry', '6'), ('REB', 'DeMar DeRozan', '1'), ('REB', 'Terrence Ross', '5'), ('REB', 'Patrick Patterson', '5'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FG3A', 'Lucas Nogueira', 'N/A'), ('FG3A', 'Delon Wright', 'N/A'), ('FG3A', 'Bismack Biyombo', '0'), ('FG3A', 'Cory Joseph', '1'), ('FG3A', 'Norman Powell', '0'), ('FG3A', 'DeMarre Carroll', 'N/A'), ('FG3A', "Kyle O'Quinn", '1'), ('FG3A', 'Lance Thomas', '0'), ('FG3A', 'Arron Afflalo', '3'), ('FG3A', 'Robin Lopez', '0'), ('FG3A', 'Derrick Williams', '3'), ('FG3A', 'Langston Galloway', '3'), ('FG3A', 'Sasha Vujacic', '6'), ('FG3A', 'Kevin Seraphin', '0'), ('FG3A', 'Lou Amundson', '0'), ('FG3A', 'Jerian Grant', '2'), ('FG3A', 'Jose Calderon', 'N/A'), ('FG3A', 'Carmelo Anthony', 'N/A'), ('FG3A', 'James Johnson', '1'), ('FG3A', 'Kristaps Porzingis', 'N/A'), ('FG3A', 'Jonas Valanciunas', '0'), ('FG3A', 'Luis Scola', '2'), ('FG3A', 'Kyle Lowry', '5'), ('FG3A', 'DeMar DeRozan', '3'), ('FG3A', 'Terrence Ross', '5'), ('FG3A', 'Patrick Patterson', '3'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('PLAYER_NAME', 'Lucas Nogueira', 'Lucas Nogueira'), ('PLAYER_NAME', 'Delon Wright', 'Delon Wright'), ('PLAYER_NAME', 'Bismack Biyombo', 'Bismack Biyombo'), ('PLAYER_NAME', 'Cory Joseph', 'Cory Joseph'), ('PLAYER_NAME', 'Norman Powell', 'Norman Powell'), ('PLAYER_NAME', 'DeMarre Carroll', 'DeMarre Carroll'), ('PLAYER_NAME', "Kyle O'Quinn", "Kyle O'Quinn"), ('PLAYER_NAME', 'Lance Thomas', 'Lance Thomas'), ('PLAYER_NAME', 'Arron Afflalo', 'Arron Afflalo'), ('PLAYER_NAME', 'Robin Lopez', 'Robin Lopez'), ('PLAYER_NAME', 'Derrick Williams', 'Derrick Williams'), ('PLAYER_NAME', 'Langston Galloway', 'Langston Galloway'), ('PLAYER_NAME', 'Sasha Vujacic', 'Sasha Vujacic'), ('PLAYER_NAME', 'Kevin Seraphin', 'Kevin Seraphin'), ('PLAYER_NAME', 'Lou Amundson', 'Lou Amundson'), ('PLAYER_NAME', 'Jerian Grant', 'Jerian Grant'), ('PLAYER_NAME', 'Jose Calderon', 'Jose Calderon'), ('PLAYER_NAME', 'Carmelo Anthony', 'Carmelo Anthony'), ('PLAYER_NAME', 'James Johnson', 'James Johnson'), ('PLAYER_NAME', 'Kristaps Porzingis', 'Kristaps Porzingis'), ('PLAYER_NAME', 'Jonas Valanciunas', 'Jonas Valanciunas'), ('PLAYER_NAME', 'Luis Scola', 'Luis Scola'), ('PLAYER_NAME', 'Kyle Lowry', 'Kyle Lowry'), ('PLAYER_NAME', 'DeMar DeRozan', 'DeMar DeRozan'), ('PLAYER_NAME', 'Terrence Ross', 'Terrence Ross'), ('PLAYER_NAME', 'Patrick Patterson', 'Patrick Patterson'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('AST', 'Lucas Nogueira', 'N/A'), ('AST', 'Delon Wright', 'N/A'), ('AST', 'Bismack Biyombo', '0'), ('AST', 'Cory Joseph', '4'), ('AST', 'Norman Powell', '0'), ('AST', 'DeMarre Carroll', 'N/A'), ('AST', "Kyle O'Quinn", '3'), ('AST', 'Lance Thomas', '0'), ('AST', 'Arron Afflalo', '4'), ('AST', 'Robin Lopez', '0'), ('AST', 'Derrick Williams', '2'), ('AST', 'Langston Galloway', '2'), ('AST', 'Sasha Vujacic', '2'), ('AST', 'Kevin Seraphin', '1'), ('AST', 'Lou Amundson', '0'), ('AST', 'Jerian Grant', '6'), ('AST', 'Jose Calderon', 'N/A'), ('AST', 'Carmelo Anthony', 'N/A'), ('AST', 'James Johnson', '1'), ('AST', 'Kristaps Porzingis', 'N/A'), ('AST', 'Jonas Valanciunas', '0'), ('AST', 'Luis Scola', '1'), ('AST', 'Kyle Lowry', '10'), ('AST', 'DeMar DeRozan', '4'), ('AST', 'Terrence Ross', '1'), ('AST', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FG3M', 'Lucas Nogueira', 'N/A'), ('FG3M', 'Delon Wright', 'N/A'), ('FG3M', 'Bismack Biyombo', '0'), ('FG3M', 'Cory Joseph', '0'), ('FG3M', 'Norman Powell', '0'), ('FG3M', 'DeMarre Carroll', 'N/A'), ('FG3M', "Kyle O'Quinn", '0'), ('FG3M', 'Lance Thomas', '0'), ('FG3M', 'Arron Afflalo', '3'), ('FG3M', 'Robin Lopez', '0'), ('FG3M', 'Derrick Williams', '0'), ('FG3M', 'Langston Galloway', '0'), ('FG3M', 'Sasha Vujacic', '3'), ('FG3M', 'Kevin Seraphin', '0'), ('FG3M', 'Lou Amundson', '0'), ('FG3M', 'Jerian Grant', '1'), ('FG3M', 'Jose Calderon', 'N/A'), ('FG3M', 'Carmelo Anthony', 'N/A'), ('FG3M', 'James Johnson', '0'), ('FG3M', 'Kristaps Porzingis', 'N/A'), ('FG3M', 'Jonas Valanciunas', '0'), ('FG3M', 'Luis Scola', '1'), ('FG3M', 'Kyle Lowry', '3'), ('FG3M', 'DeMar DeRozan', '1'), ('FG3M', 'Terrence Ross', '1'), ('FG3M', 'Patrick Patterson', '2'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('OREB', 'Lucas Nogueira', 'N/A'), ('OREB', 'Delon Wright', 'N/A'), ('OREB', 'Bismack Biyombo', '0'), ('OREB', 'Cory Joseph', '1'), ('OREB', 'Norman Powell', '0'), ('OREB', 'DeMarre Carroll', 'N/A'), ('OREB', "Kyle O'Quinn", '2'), ('OREB', 'Lance Thomas', '0'), ('OREB', 'Arron Afflalo', '0'), ('OREB', 'Robin Lopez', '4'), ('OREB', 'Derrick Williams', '1'), ('OREB', 'Langston Galloway', '1'), ('OREB', 'Sasha Vujacic', '2'), ('OREB', 'Kevin Seraphin', '0'), ('OREB', 'Lou Amundson', '2'), ('OREB', 'Jerian Grant', '0'), ('OREB', 'Jose Calderon', 'N/A'), ('OREB', 'Carmelo Anthony', 'N/A'), ('OREB', 'James Johnson', '1'), ('OREB', 'Kristaps Porzingis', 'N/A'), ('OREB', 'Jonas Valanciunas', '8'), ('OREB', 'Luis Scola', '1'), ('OREB', 'Kyle Lowry', '3'), ('OREB', 'DeMar DeRozan', '0'), ('OREB', 'Terrence Ross', '1'), ('OREB', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('TO', 'Lucas Nogueira', 'N/A'), ('TO', 'Delon Wright', 'N/A'), ('TO', 'Bismack Biyombo', '0'), ('TO', 'Cory Joseph', '1'), ('TO', 'Norman Powell', '0'), ('TO', 'DeMarre Carroll', 'N/A'), ('TO', "Kyle O'Quinn", '1'), ('TO', 'Lance Thomas', '1'), ('TO', 'Arron Afflalo', '0'), ('TO', 'Robin Lopez', '2'), ('TO', 'Derrick Williams', '0'), ('TO', 'Langston Galloway', '0'), ('TO', 'Sasha Vujacic', '1'), ('TO', 'Kevin Seraphin', '1'), ('TO', 'Lou Amundson', '1'), ('TO', 'Jerian Grant', '2'), ('TO', 'Jose Calderon', 'N/A'), ('TO', 'Carmelo Anthony', 'N/A'), ('TO', 'James Johnson', '1'), ('TO', 'Kristaps Porzingis', 'N/A'), ('TO', 'Jonas Valanciunas', '0'), ('TO', 'Luis Scola', '0'), ('TO', 'Kyle Lowry', '3'), ('TO', 'DeMar DeRozan', '3'), ('TO', 'Terrence Ross', '0'), ('TO', 'Patrick Patterson', '2'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('START_POSITION', 'Lucas Nogueira', 'N/A'), ('START_POSITION', 'Delon Wright', 'N/A'), ('START_POSITION', 'Bismack Biyombo', 'N/A'), ('START_POSITION', 'Cory Joseph', 'N/A'), ('START_POSITION', 'Norman Powell', 'N/A'), ('START_POSITION', 'DeMarre Carroll', 'N/A'), ('START_POSITION', "Kyle O'Quinn", 'F'), ('START_POSITION', 'Lance Thomas', 'F'), ('START_POSITION', 'Arron Afflalo', 'G'), ('START_POSITION', 'Robin Lopez', 'C'), ('START_POSITION', 'Derrick Williams', 'N/A'), ('START_POSITION', 'Langston Galloway', 'G'), ('START_POSITION', 'Sasha Vujacic', 'N/A'), ('START_POSITION', 'Kevin Seraphin', 'N/A'), ('START_POSITION', 'Lou Amundson', 'N/A'), ('START_POSITION', 'Jerian Grant', 'N/A'), ('START_POSITION', 'Jose Calderon', 'N/A'), ('START_POSITION', 'Carmelo Anthony', 'N/A'), ('START_POSITION', 'James Johnson', 'F'), ('START_POSITION', 'Kristaps Porzingis', 'N/A'), ('START_POSITION', 'Jonas Valanciunas', 'C'), ('START_POSITION', 'Luis Scola', 'F'), ('START_POSITION', 'Kyle Lowry', 'G'), ('START_POSITION', 'DeMar DeRozan', 'G'), ('START_POSITION', 'Terrence Ross', 'N/A'), ('START_POSITION', 'Patrick Patterson', 'N/A'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('PF', 'Lucas Nogueira', 'N/A'), ('PF', 'Delon Wright', 'N/A'), ('PF', 'Bismack Biyombo', '2'), ('PF', 'Cory Joseph', '1'), ('PF', 'Norman Powell', '0'), ('PF', 'DeMarre Carroll', 'N/A'), ('PF', "Kyle O'Quinn", '3'), ('PF', 'Lance Thomas', '1'), ('PF', 'Arron Afflalo', '2'), ('PF', 'Robin Lopez', '2'), ('PF', 'Derrick Williams', '0'), ('PF', 'Langston Galloway', '3'), ('PF', 'Sasha Vujacic', '0'), ('PF', 'Kevin Seraphin', '3'), ('PF', 'Lou Amundson', '3'), ('PF', 'Jerian Grant', '2'), ('PF', 'Jose Calderon', 'N/A'), ('PF', 'Carmelo Anthony', 'N/A'), ('PF', 'James Johnson', '3'), ('PF', 'Kristaps Porzingis', 'N/A'), ('PF', 'Jonas Valanciunas', '4'), ('PF', 'Luis Scola', '0'), ('PF', 'Kyle Lowry', '2'), ('PF', 'DeMar DeRozan', '4'), ('PF', 'Terrence Ross', '0'), ('PF', 'Patrick Patterson', '3'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('PTS', 'Lucas Nogueira', 'N/A'), ('PTS', 'Delon Wright', 'N/A'), ('PTS', 'Bismack Biyombo', '5'), ('PTS', 'Cory Joseph', '11'), ('PTS', 'Norman Powell', '0'), ('PTS', 'DeMarre Carroll', 'N/A'), ('PTS', "Kyle O'Quinn", '8'), ('PTS', 'Lance Thomas', '7'), ('PTS', 'Arron Afflalo', '20'), ('PTS', 'Robin Lopez', '7'), ('PTS', 'Derrick Williams', '6'), ('PTS', 'Langston Galloway', '12'), ('PTS', 'Sasha Vujacic', '13'), ('PTS', 'Kevin Seraphin', '4'), ('PTS', 'Lou Amundson', '3'), ('PTS', 'Jerian Grant', '13'), ('PTS', 'Jose Calderon', 'N/A'), ('PTS', 'Carmelo Anthony', 'N/A'), ('PTS', 'James Johnson', '1'), ('PTS', 'Kristaps Porzingis', 'N/A'), ('PTS', 'Jonas Valanciunas', '11'), ('PTS', 'Luis Scola', '7'), ('PTS', 'Kyle Lowry', '26'), ('PTS', 'DeMar DeRozan', '26'), ('PTS', 'Terrence Ross', '6'), ('PTS', 'Patrick Patterson', '10'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FGA', 'Lucas Nogueira', 'N/A'), ('FGA', 'Delon Wright', 'N/A'), ('FGA', 'Bismack Biyombo', '3'), ('FGA', 'Cory Joseph', '8'), ('FGA', 'Norman Powell', '1'), ('FGA', 'DeMarre Carroll', 'N/A'), ('FGA', "Kyle O'Quinn", '13'), ('FGA', 'Lance Thomas', '6'), ('FGA', 'Arron Afflalo', '17'), ('FGA', 'Robin Lopez', '5'), ('FGA', 'Derrick Williams', '12'), ('FGA', 'Langston Galloway', '10'), ('FGA', 'Sasha Vujacic', '10'), ('FGA', 'Kevin Seraphin', '4'), ('FGA', 'Lou Amundson', '2'), ('FGA', 'Jerian Grant', '8'), ('FGA', 'Jose Calderon', 'N/A'), ('FGA', 'Carmelo Anthony', 'N/A'), ('FGA', 'James Johnson', '3'), ('FGA', 'Kristaps Porzingis', 'N/A'), ('FGA', 'Jonas Valanciunas', '16'), ('FGA', 'Luis Scola', '5'), ('FGA', 'Kyle Lowry', '16'), ('FGA', 'DeMar DeRozan', '18'), ('FGA', 'Terrence Ross', '9'), ('FGA', 'Patrick Patterson', '6'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('STL', 'Lucas Nogueira', 'N/A'), ('STL', 'Delon Wright', 'N/A'), ('STL', 'Bismack Biyombo', '0'), ('STL', 'Cory Joseph', '0'), ('STL', 'Norman Powell', '0'), ('STL', 'DeMarre Carroll', 'N/A'), ('STL', "Kyle O'Quinn", '1'), ('STL', 'Lance Thomas', '0'), ('STL', 'Arron Afflalo', '0'), ('STL', 'Robin Lopez', '0'), ('STL', 'Derrick Williams', '1'), ('STL', 'Langston Galloway', '0'), ('STL', 'Sasha Vujacic', '2'), ('STL', 'Kevin Seraphin', '0'), ('STL', 'Lou Amundson', '0'), ('STL', 'Jerian Grant', '2'), ('STL', 'Jose Calderon', 'N/A'), ('STL', 'Carmelo Anthony', 'N/A'), ('STL', 'James Johnson', '1'), ('STL', 'Kristaps Porzingis', 'N/A'), ('STL', 'Jonas Valanciunas', '0'), ('STL', 'Luis Scola', '1'), ('STL', 'Kyle Lowry', '3'), ('STL', 'DeMar DeRozan', '1'), ('STL', 'Terrence Ross', '1'), ('STL', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FTA', 'Lucas Nogueira', 'N/A'), ('FTA', 'Delon Wright', 'N/A'), ('FTA', 'Bismack Biyombo', '2'), ('FTA', 'Cory Joseph', '2'), ('FTA', 'Norman Powell', '0'), ('FTA', 'DeMarre Carroll', 'N/A'), ('FTA', "Kyle O'Quinn", '0'), ('FTA', 'Lance Thomas', '1'), ('FTA', 'Arron Afflalo', '3'), ('FTA', 'Robin Lopez', '2'), ('FTA', 'Derrick Williams', '0'), ('FTA', 'Langston Galloway', '0'), ('FTA', 'Sasha Vujacic', '2'), ('FTA', 'Kevin Seraphin', '0'), ('FTA', 'Lou Amundson', '3'), ('FTA', 'Jerian Grant', '9'), ('FTA', 'Jose Calderon', 'N/A'), ('FTA', 'Carmelo Anthony', 'N/A'), ('FTA', 'James Johnson', '4'), ('FTA', 'Kristaps Porzingis', 'N/A'), ('FTA', 'Jonas Valanciunas', '3'), ('FTA', 'Luis Scola', '0'), ('FTA', 'Kyle Lowry', '8'), ('FTA', 'DeMar DeRozan', '8'), ('FTA', 'Terrence Ross', '2'), ('FTA', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('BLK', 'Lucas Nogueira', 'N/A'), ('BLK', 'Delon Wright', 'N/A'), ('BLK', 'Bismack Biyombo', '1'), ('BLK', 'Cory Joseph', '1'), ('BLK', 'Norman Powell', '0'), ('BLK', 'DeMarre Carroll', 'N/A'), ('BLK', "Kyle O'Quinn", '2'), ('BLK', 'Lance Thomas', '1'), ('BLK', 'Arron Afflalo', '0'), ('BLK', 'Robin Lopez', '2'), ('BLK', 'Derrick Williams', '0'), ('BLK', 'Langston Galloway', '2'), ('BLK', 'Sasha Vujacic', '0'), ('BLK', 'Kevin Seraphin', '0'), ('BLK', 'Lou Amundson', '1'), ('BLK', 'Jerian Grant', '0'), ('BLK', 'Jose Calderon', 'N/A'), ('BLK', 'Carmelo Anthony', 'N/A'), ('BLK', 'James Johnson', '4'), ('BLK', 'Kristaps Porzingis', 'N/A'), ('BLK', 'Jonas Valanciunas', '1'), ('BLK', 'Luis Scola', '0'), ('BLK', 'Kyle Lowry', '0'), ('BLK', 'DeMar DeRozan', '2'), ('BLK', 'Terrence Ross', '2'), ('BLK', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('DREB', 'Lucas Nogueira', 'N/A'), ('DREB', 'Delon Wright', 'N/A'), ('DREB', 'Bismack Biyombo', '2'), ('DREB', 'Cory Joseph', '6'), ('DREB', 'Norman Powell', '1'), ('DREB', 'DeMarre Carroll', 'N/A'), ('DREB', "Kyle O'Quinn", '4'), ('DREB', 'Lance Thomas', '2'), ('DREB', 'Arron Afflalo', '2'), ('DREB', 'Robin Lopez', '4'), ('DREB', 'Derrick Williams', '4'), ('DREB', 'Langston Galloway', '3'), ('DREB', 'Sasha Vujacic', '4'), ('DREB', 'Kevin Seraphin', '1'), ('DREB', 'Lou Amundson', '0'), ('DREB', 'Jerian Grant', '4'), ('DREB', 'Jose Calderon', 'N/A'), ('DREB', 'Carmelo Anthony', 'N/A'), ('DREB', 'James Johnson', '0'), ('DREB', 'Kristaps Porzingis', 'N/A'), ('DREB', 'Jonas Valanciunas', '10'), ('DREB', 'Luis Scola', '3'), ('DREB', 'Kyle Lowry', '3'), ('DREB', 'DeMar DeRozan', '1'), ('DREB', 'Terrence Ross', '4'), ('DREB', 'Patrick Patterson', '5'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FTM', 'Lucas Nogueira', 'N/A'), ('FTM', 'Delon Wright', 'N/A'), ('FTM', 'Bismack Biyombo', '1'), ('FTM', 'Cory Joseph', '1'), ('FTM', 'Norman Powell', '0'), ('FTM', 'DeMarre Carroll', 'N/A'), ('FTM', "Kyle O'Quinn", '0'), ('FTM', 'Lance Thomas', '1'), ('FTM', 'Arron Afflalo', '3'), ('FTM', 'Robin Lopez', '1'), ('FTM', 'Derrick Williams', '0'), ('FTM', 'Langston Galloway', '0'), ('FTM', 'Sasha Vujacic', '0'), ('FTM', 'Kevin Seraphin', '0'), ('FTM', 'Lou Amundson', '1'), ('FTM', 'Jerian Grant', '4'), ('FTM', 'Jose Calderon', 'N/A'), ('FTM', 'Carmelo Anthony', 'N/A'), ('FTM', 'James Johnson', '1'), ('FTM', 'Kristaps Porzingis', 'N/A'), ('FTM', 'Jonas Valanciunas', '3'), ('FTM', 'Luis Scola', '0'), ('FTM', 'Kyle Lowry', '7'), ('FTM', 'DeMar DeRozan', '7'), ('FTM', 'Terrence Ross', '1'), ('FTM', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FT_PCT', 'Lucas Nogueira', 'N/A'), ('FT_PCT', 'Delon Wright', 'N/A'), ('FT_PCT', 'Bismack Biyombo', '50'), ('FT_PCT', 'Cory Joseph', '50'), ('FT_PCT', 'Norman Powell', '0'), ('FT_PCT', 'DeMarre Carroll', 'N/A'), ('FT_PCT', "Kyle O'Quinn", '0'), ('FT_PCT', 'Lance Thomas', '100'), ('FT_PCT', 'Arron Afflalo', '100'), ('FT_PCT', 'Robin Lopez', '50'), ('FT_PCT', 'Derrick Williams', '0'), ('FT_PCT', 'Langston Galloway', '0'), ('FT_PCT', 'Sasha Vujacic', '0'), ('FT_PCT', 'Kevin Seraphin', '0'), ('FT_PCT', 'Lou Amundson', '33'), ('FT_PCT', 'Jerian Grant', '44'), ('FT_PCT', 'Jose Calderon', 'N/A'), ('FT_PCT', 'Carmelo Anthony', 'N/A'), ('FT_PCT', 'James Johnson', '25'), ('FT_PCT', 'Kristaps Porzingis', 'N/A'), ('FT_PCT', 'Jonas Valanciunas', '100'), ('FT_PCT', 'Luis Scola', '0'), ('FT_PCT', 'Kyle Lowry', '88'), ('FT_PCT', 'DeMar DeRozan', '88'), ('FT_PCT', 'Terrence Ross', '50'), ('FT_PCT', 'Patrick Patterson', '0'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FG_PCT', 'Lucas Nogueira', 'N/A'), ('FG_PCT', 'Delon Wright', 'N/A'), ('FG_PCT', 'Bismack Biyombo', '67'), ('FG_PCT', 'Cory Joseph', '63'), ('FG_PCT', 'Norman Powell', '0'), ('FG_PCT', 'DeMarre Carroll', 'N/A'), ('FG_PCT', "Kyle O'Quinn", '31'), ('FG_PCT', 'Lance Thomas', '50'), ('FG_PCT', 'Arron Afflalo', '41'), ('FG_PCT', 'Robin Lopez', '60'), ('FG_PCT', 'Derrick Williams', '25'), ('FG_PCT', 'Langston Galloway', '60'), ('FG_PCT', 'Sasha Vujacic', '50'), ('FG_PCT', 'Kevin Seraphin', '50'), ('FG_PCT', 'Lou Amundson', '50'), ('FG_PCT', 'Jerian Grant', '50'), ('FG_PCT', 'Jose Calderon', 'N/A'), ('FG_PCT', 'Carmelo Anthony', 'N/A'), ('FG_PCT', 'James Johnson', '0'), ('FG_PCT', 'Kristaps Porzingis', 'N/A'), ('FG_PCT', 'Jonas Valanciunas', '25'), ('FG_PCT', 'Luis Scola', '60'), ('FG_PCT', 'Kyle Lowry', '50'), ('FG_PCT', 'DeMar DeRozan', '50'), ('FG_PCT', 'Terrence Ross', '22'), ('FG_PCT', 'Patrick Patterson', '67'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('FG3_PCT', 'Lucas Nogueira', 'N/A'), ('FG3_PCT', 'Delon Wright', 'N/A'), ('FG3_PCT', 'Bismack Biyombo', '0'), ('FG3_PCT', 'Cory Joseph', '0'), ('FG3_PCT', 'Norman Powell', '0'), ('FG3_PCT', 'DeMarre Carroll', 'N/A'), ('FG3_PCT', "Kyle O'Quinn", '0'), ('FG3_PCT', 'Lance Thomas', '0'), ('FG3_PCT', 'Arron Afflalo', '100'), ('FG3_PCT', 'Robin Lopez', '0'), ('FG3_PCT', 'Derrick Williams', '0'), ('FG3_PCT', 'Langston Galloway', '0'), ('FG3_PCT', 'Sasha Vujacic', '50'), ('FG3_PCT', 'Kevin Seraphin', '0'), ('FG3_PCT', 'Lou Amundson', '0'), ('FG3_PCT', 'Jerian Grant', '50'), ('FG3_PCT', 'Jose Calderon', 'N/A'), ('FG3_PCT', 'Carmelo Anthony', 'N/A'), ('FG3_PCT', 'James Johnson', '0'), ('FG3_PCT', 'Kristaps Porzingis', 'N/A'), ('FG3_PCT', 'Jonas Valanciunas', '0'), ('FG3_PCT', 'Luis Scola', '50'), ('FG3_PCT', 'Kyle Lowry', '60'), ('FG3_PCT', 'DeMar DeRozan', '33'), ('FG3_PCT', 'Terrence Ross', '20'), ('FG3_PCT', 'Patrick Patterson', '67'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('SECOND_NAME', 'Lucas Nogueira', 'Nogueira'), ('SECOND_NAME', 'Delon Wright', 'Wright'), ('SECOND_NAME', 'Bismack Biyombo', 'Biyombo'), ('SECOND_NAME', 'Cory Joseph', 'Joseph'), ('SECOND_NAME', 'Norman Powell', 'Powell'), ('SECOND_NAME', 'DeMarre Carroll', 'Carroll'), ('SECOND_NAME', "Kyle O'Quinn", "O'Quinn"), ('SECOND_NAME', 'Lance Thomas', 'Thomas'), ('SECOND_NAME', 'Arron Afflalo', 'Afflalo'), ('SECOND_NAME', 'Robin Lopez', 'Lopez'), ('SECOND_NAME', 'Derrick Williams', 'Williams'), ('SECOND_NAME', 'Langston Galloway', 'Galloway'), ('SECOND_NAME', 'Sasha Vujacic', 'Vujacic'), ('SECOND_NAME', 'Kevin Seraphin', 'Seraphin'), ('SECOND_NAME', 'Lou Amundson', 'Amundson'), ('SECOND_NAME', 'Jerian Grant', 'Grant'), ('SECOND_NAME', 'Jose Calderon', 'Calderon'), ('SECOND_NAME', 'Carmelo Anthony', 'Anthony'), ('SECOND_NAME', 'James Johnson', 'Johnson'), ('SECOND_NAME', 'Kristaps Porzingis', 'Porzingis'), ('SECOND_NAME', 'Jonas Valanciunas', 'Valanciunas'), ('SECOND_NAME', 'Luis Scola', 'Scola'), ('SECOND_NAME', 'Kyle Lowry', 'Lowry'), ('SECOND_NAME', 'DeMar DeRozan', 'DeRozan'), ('SECOND_NAME', 'Terrence Ross', 'Ross'), ('SECOND_NAME', 'Patrick Patterson', 'Patterson'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('TEAM_CITY', 'Lucas Nogueira', 'Toronto'), ('TEAM_CITY', 'Delon Wright', 'Toronto'), ('TEAM_CITY', 'Bismack Biyombo', 'Toronto'), ('TEAM_CITY', 'Cory Joseph', 'Toronto'), ('TEAM_CITY', 'Norman Powell', 'Toronto'), ('TEAM_CITY', 'DeMarre Carroll', 'Toronto'), ('TEAM_CITY', "Kyle O'Quinn", 'New York'), ('TEAM_CITY', 'Lance Thomas', 'New York'), ('TEAM_CITY', 'Arron Afflalo', 'New York'), ('TEAM_CITY', 'Robin Lopez', 'New York'), ('TEAM_CITY', 'Derrick Williams', 'New York'), ('TEAM_CITY', 'Langston Galloway', 'New York'), ('TEAM_CITY', 'Sasha Vujacic', 'New York'), ('TEAM_CITY', 'Kevin Seraphin', 'New York'), ('TEAM_CITY', 'Lou Amundson', 'New York'), ('TEAM_CITY', 'Jerian Grant', 'New York'), ('TEAM_CITY', 'Jose Calderon', 'New York'), ('TEAM_CITY', 'Carmelo Anthony', 'New York'), ('TEAM_CITY', 'James Johnson', 'Toronto'), ('TEAM_CITY', 'Kristaps Porzingis', 'New York'), ('TEAM_CITY', 'Jonas Valanciunas', 'Toronto'), ('TEAM_CITY', 'Luis Scola', 'Toronto'), ('TEAM_CITY', 'Kyle Lowry', 'Toronto'), ('TEAM_CITY', 'DeMar DeRozan', 'Toronto'), ('TEAM_CITY', 'Terrence Ross', 'Toronto'), ('TEAM_CITY', 'Patrick Patterson', 'Toronto'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<PAD>', '<PAD>', '<PAD>'), ('<EOB>', '<EOB>', '<EOB>'), ('name', 'home_name', 'Raptors'), ('city', 'home_city', 'Toronto'), ('name', 'vis_name', 'Knicks'), ('city', 'vis_city', 'New York'), ('TEAM-PTS_QTR2', 'Raptors', '26'), ('TEAM-PTS_QTR3', 'Raptors', '20'), ('TEAM-PTS_QTR1', 'Raptors', '27'), ('TEAM-PTS_QTR4', 'Raptors', '30'), ('TEAM-REB', 'Raptors', '50'), ('TEAM-CITY', 'Raptors', 'Toronto'), ('TEAM-PTS', 'Raptors', '103'), ('TEAM-AST', 'Raptors', '21'), ('TEAM-LOSSES', 'Raptors', '15'), ('TEAM-FT_PCT', 'Raptors', '72'), ('TEAM-WINS', 'Raptors', '31'), ('TEAM-FG_PCT', 'Raptors', '44'), ('TEAM-TOV', 'Raptors', '10'), ('TEAM-FG3_PCT', 'Raptors', '40'), ('TEAM-PTS_QTR2', 'Knicks', '22'), ('TEAM-PTS_QTR3', 'Knicks', '20'), ('TEAM-PTS_QTR1', 'Knicks', '21'), ('TEAM-PTS_QTR4', 'Knicks', '30'), ('TEAM-REB', 'Knicks', '40'), ('TEAM-CITY', 'Knicks', 'New York'), ('TEAM-PTS', 'Knicks', '93'), ('TEAM-AST', 'Knicks', '20'), ('TEAM-LOSSES', 'Knicks', '26'), ('TEAM-FT_PCT', 'Knicks', '50'), ('TEAM-WINS', 'Knicks', '22'), ('TEAM-FG_PCT', 'Knicks', '44'), ('TEAM-TOV', 'Knicks', '9'), ('TEAM-FG3_PCT', 'Knicks', '39')]

# %%
ylabels = [line[0]+' : '+line[1]+' : '+line[2] for line in lines]

# %%
import seaborn as sns; sns.set()

# %%
from matplotlib import pyplot as plt

# %%
summary = 'The Toronto Raptors ( 16 - 5 ) defeated the Denver Nuggets ( 9 - 12 ) 112 - 107 on Monday at the Air Canada Centre in Toronto . <BLK> The Raptors were able to get out to a 62 - 52 lead after the first half , but the Nuggets turned in a big third quarter and evened it back up going into the fourth . <BLK> After ending regulation tied 102 - 102 , they went into overtime where the Raptors held the Nuggets to only five points , therefore securing the victory . <BLK> The Raptors received a big contribution off the bench in the overtime win . <BLK> Louis Williams led all scorers with 26 points ( 7 - 16 FG , 3 - 10 3Pt , 9 - 10 FT ) , while also grabbing three rebounds . <BLK> It was a nice bounce back game for him , after scoring only five points on Friday against the Cavaliers . <BLK> Patrick Patterson was the other big bench presence , as he went 7 - for - 11 from the field and 5 - for - 7 from the three - point line to score 19 points . <BLK> He also chipped in eight rebounds , in what was arguably one of his best games of the year . <BLK> Starting at center , Jonas Valanciunas recorded his fifth double - double of the year , finishing with 18 points and 12 rebounds . <BLK> He did it on the defensive side of the ball as well and recorded a season - high of four blocks . <BLK> Kyle Lowry and Terrence Ross had 13 and 16 points respectively , with Lowry handing out 13 assists . <BLK> The Nuggets backcourt did most of the damage to the Raptors . <BLK> Arron Afflalo went 9 - for - 14 from the field and 4 - for - 7 from the three - point line to score a team - high of 25 points , while adding six rebounds . <BLK> Ty Lawson also had a big game and recorded 22 points ( 8 - 19 FG , 2 - 8 3Pt , 4 - 6 FT ) and 12 assists . <BLK> It was his ninth straight game with at least 10 assists . <BLK> Wilson Chandler got off a team - high of 21 shots , but only converted on seven , giving him 18 points on the night . <BLK> He s now combined for 67 points in the last three games , as he continues to get off a ridiculous amount of shots . <BLK> Both J.J. Hickson and Timofey Mozgov reached double - figures , scoring 10 and 15 points respectively . <BLK> Mozgov contributed 12 rebounds to go along with his 15 points , giving him his second double - double in a row . <BLK> The Raptors next game will be on the road against the Cleveland Cavliers on Tuesday , while the Nuggets will be at home against the Miami Heat on Tuesday as well . <BLK> <EOS>'.split()

# %%
num_timesteps = 20
num_labels = 64

def create_heatmap(data, cmap='Blues'):
    yticklabels = ylabels
    xticklabels = summary[0:num_timesteps]
    plt.figure(figsize=(40,120))
    ax = sns.heatmap(data, cmap=cmap, cbar = True, xticklabels=xticklabels, yticklabels=yticklabels, annot_kws={"size": 15, "weight":"bold"})
    plt.title('')
    plt.xlabel('')
    plt.ylabel('')
    plt.show()

# %%
create_heatmap(values[:, 0:num_timesteps])
